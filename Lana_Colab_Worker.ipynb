# %% [markdown]
# <a href="https://colab.research.google.com/github/carpu86/Lana-ki/blob/main/Lana_Colab_Worker.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
cd "C:\Carpuncle Cloud\LanaApp"

$notebook = @'
{
  "nbformat": 4,
  "nbformat_minor": 4,
  "metadata": {
    "kernelspec": {"display_name": "Python 3", "name": "python3"}
  },
  "cells": [
    {
      "cell_type": "markdown",
      "source": ["# 👑 Lana-KI Colab Pro Worker\n**Video + FapHouse Upload**"]
    },
    {
      "cell_type": "code",
      "source": [
        "!pip install fastapi uvicorn pyngrok playwright -q\n",
        "from fastapi import FastAPI\n",
        "from pyngrok import ngrok\n",
        "\n",
        "app = FastAPI()\n",
        "\n",
        "@app.post(\"/generate\")\n",
        "async def generate(data: dict):\n",
        "    print(\"🎥 Video wird generiert...\")\n",
        "    return {\"status\": \"success\"}\n",
        "\n",
        "public_url = ngrok.connect(8000)\n",
        "print(f\"🌐 Deine ngrok URL: {public_url}\")\n",
        "print(\"✅ Worker bereit! Sende jetzt Befehle vom Dashboard.\")"
      ]
    }
  ]
}
'@

$notebook | Out-File "Lana_Colab_Worker.ipynb" -Encoding UTF8 -Force
git add Lana_Colab_Worker.ipynb
git commit -m "Final Colab Pro Worker"
git push origin main

Write-Host "✅ Fertig! Jetzt das Notebook öffnen:" -ForegroundColor Green
# Out:
#   File "/tmp/ipykernel_7804/110013273.py", line 3
#     $notebook = @'
#                  ^
# SyntaxError: unterminated string literal (detected at line 3)
